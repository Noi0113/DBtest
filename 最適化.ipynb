# %%
pip install pulp
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.3/14.3 MB 36.1 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import pulp
import random

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('/content/drive/問題発見と解決/model.csv')
###わかる人頼んだ
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-17-ab400f42ba70> in <cell line: 1>()
# ----> 1 df = pd.read_csv('/content/drive/問題発見と解決/model.csv')
#       2 ###わかる人頼んだ
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
import os
path = os.path.join('/content/drive/問題発見と解決/', 'model.csv')
print(path)
# Out:
# /content/drive/問題発見と解決/model.csv

# %%
import csv

csvfile = open('/content/drive/My Drive/問題発見と解決/model.csv', 'r', encoding='utf-8')
reader = csv.DictReader(csvfile)

for row in reader:
  print(row)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-23-f701faf6751b> in <cell line: 3>()
#       1 import csv
#       2
# ----> 3 csvfile = open('/content/drive/My Drive/問題発見と解決/model.csv', 'r', encoding='utf-8')
#       4 reader = csv.DictReader(csvfile)
#       5
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/My Drive/問題発見と解決/model.csv'
